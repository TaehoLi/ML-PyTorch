# %%
print("pip install gym")
print("apt-get install -y cmake zlib1g-dev libjpeg-dev xvfb libav-tools xorg-dev libboost-all-dev libsdl2-dev swig")
# Out:
# pip install gym
# apt-get install -y cmake zlib1g-dev libjpeg-dev xvfb libav-tools xorg-dev libboost-all-dev libsdl2-dev swig

# %%
# gym library import
import gym

# make env
env = gym.make('FrozenLake-v0')

# %%
# game begin
for i_episode in range(20):
    observation = env.reset()
    
    for t in range(100):
        # draw field
        env.render()
        
        # action randomly
        action = env.action_space.sample()

        # first step
        observation, reward, done, info = env.step(action)
        print(observation, reward, done, info, action)

        # ending
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
# Out:
# SFFF
# FHFH
# FFFH
# HFFG
# 0 0.0 False {'prob': 0.3333333333333333} 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0 0.0 False {'prob': 0.3333333333333333} 3
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0 0.0 False {'prob': 0.3333333333333333} 1
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 4 0.0 False {'prob': 0.3333333333333333} 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 5 0.0 True {'prob': 0.3333333333333333} 3
# Episode finished after 5 timesteps
#
# SFFF
# FHFH
# FFFH
# HFFG
# 0 0.0 False {'prob': 0.3333333333333333} 3
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0 0.0 False {'prob': 0.3333333333333333} 3
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0 0.0 False {'prob': 0.3333333333333333} 3
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 4 0.0 False {'prob': 0.3333333333333333} 1
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 4 0.0 False {'prob': 0.3333333333333333} 3
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 4 0.0 False {'prob': 0.3333333333333333} 1
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ...

# %%
# Number of env_variable values
print(env.observation_space.n)
# Number of act_variable values
print(env.action_space.n)
# Out:
# 16
# 4
